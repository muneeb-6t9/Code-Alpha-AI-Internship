# %% [markdown]
# <a href="https://colab.research.google.com/github/muneeb-6t9/Code-Alpha-AI-Internship/blob/main/Object_Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/ultralytics/ultralytics
# !pip install ultralytics
# Out:
# Cloning into 'ultralytics'...
# remote: Enumerating objects: 50858, done.
# remote: Counting objects: 100% (469/469), done.
# remote: Compressing objects: 100% (223/223), done.
# remote: Total 50858 (delta 404), reused 264 (delta 246), pack-reused 50389 (from 2)
# Receiving objects: 100% (50858/50858), 28.96 MiB | 9.75 MiB/s, done.
# Resolving deltas: 100% (37620/37620), done.
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 914.7/914.7 kB 29.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 1.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 96.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 79.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 53.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 857.8 kB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.4 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
#Creating a new yolo model
model = YOLO('yolov8n.yaml')

# Loading pretrained  YOLO models
model = YOLO('yolov8n.pt')
# Out:
# ...
# 100%|██████████| 6.25M/6.25M [00:00<00:00, 152MB/s]

# %%
#Train the model using COCO128.yaml dataset
results = model.train(data='coco128.yaml', epochs=10)
# Out:
# Ultralytics 8.3.74 🚀 Python-3.11.11 torch-2.5.1+cu124 CPU (Intel Xeon 2.20GHz)
# ...

# %%
results=model.predict(source='https://ultralytics.com/images/bus.jpg', save=True)
success = model.export(format='onnx')
success
# Out:
# Found https://ultralytics.com/images/bus.jpg locally at bus.jpg
# image 1/1 /content/bus.jpg: 640x480 4 persons, 1 bus, 1 potted plant, 227.5ms
# Speed: 6.8ms preprocess, 227.5ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 480)
# Results saved to runs/detect/train2
# Ultralytics 8.3.74 🚀 Python-3.11.11 torch-2.5.1+cu124 CPU (Intel Xeon 2.20GHz)
#
# PyTorch: starting from 'runs/detect/train/weights/best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 84, 8400) (6.2 MB)
#
# ONNX: starting export with onnx 1.17.0 opset 19...
# ONNX: slimming with onnxslim 0.1.48...
# ONNX: export success ✅ 2.6s, saved as 'runs/detect/train/weights/best.onnx' (12.2 MB)
#
# Export complete (3.4s)
# Results saved to /content/runs/detect/train/weights
# Predict:         yolo predict task=detect model=runs/detect/train/weights/best.onnx imgsz=640
# ...

# %%
import matplotlib.pyplot as plt

img_1=plt.imread('/content/runs/detect/train2/bus.jpg')
plt.imshow(img_1)

# %%
results=model.predict(source='/content/runs/2025012013481250.jpg', save=True)
# Out:
# image 1/1 /content/runs/2025012013481250.jpg: 640x640 1 person, 294.8ms
# Speed: 8.5ms preprocess, 294.8ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/train3

# %%
img_2=plt.imread('/content/runs/detect/train3/2025012013481250.jpg')
plt.imshow(img_2)

# %%
# !git config --global user.name "muneeb-6t9"
# !git config --global user.email "muhammadmuneeb8689@gmail.com"

# %%
# !git clone https://github.com/muneeb-6t9/Code-Alpha-AI-Internship
# %cd Code-Alpha-AI-Internship
# Out:
# Cloning into 'Code-Alpha-AI-Internship'...
# remote: Enumerating objects: 74, done.
# remote: Counting objects: 100% (74/74), done.
# remote: Compressing objects: 100% (70/70), done.
# remote: Total 74 (delta 21), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (74/74), 28.80 KiB | 4.11 MiB/s, done.
# Resolving deltas: 100% (21/21), done.
# /content/Code-Alpha-AI-Internship

# %%
# !ls /content/
# Out:
# bus.jpg  Code-Alpha-AI-Internship  datasets  sample_data  ultralytics  yolov8n.pt

# %%
# !ls /content/*.ipynb
# Out:
# ls: cannot access '/content/*.ipynb': No such file or directory

# %%
# !ls -la /content/
# Out:
# total 6564
# drwxr-xr-x 1 root root    4096 Feb 13 02:41 .
# drwxr-xr-x 1 root root    4096 Feb 13 01:30 ..
# -rw-r--r-- 1 root root  137419 Feb 13 02:10 bus.jpg
# drwxr-xr-x 4 root root    4096 Feb 13 02:41 Code-Alpha-AI-Internship
# drwxr-xr-x 4 root root    4096 Feb 11 14:27 .config
# drwxr-xr-x 3 root root    4096 Feb 13 01:38 datasets
# drwxr-xr-x 1 root root    4096 Feb 11 14:27 sample_data
# drwxr-xr-x 9 root root    4096 Feb 13 01:31 ultralytics
# -rw-r--r-- 1 root root 6549796 Feb 13 01:38 yolov8n.pt

# %%
# !find / -type f -name "*.ipynb" 2>/dev/null
# Out:
# /usr/local/lib/python3.11/dist-packages/panel/tests/ui/io/app.ipynb
# /usr/local/lib/python3.11/dist-packages/notebook/bundler/tests/resources/empty.ipynb
# /usr/local/lib/python3.11/dist-packages/nbclassic/bundler/tests/resources/empty.ipynb
# /usr/local/lib/python3.11/dist-packages/holoviews/tests/ipython/notebooks/test_output_svg_line_magic.ipynb
# /usr/local/lib/python3.11/dist-packages/holoviews/tests/ipython/notebooks/test_opts_image_cell_magic_offset.ipynb
# /usr/local/lib/python3.11/dist-packages/holoviews/tests/ipython/notebooks/test_opts_image_cell_magic.ipynb
# /usr/local/lib/python3.11/dist-packages/holoviews/tests/ipython/notebooks/test_opts_image_line_magic.ipynb
# /usr/local/lib/python3.11/dist-packages/holoviews/examples/user_guide/08-Tabular_Datasets.ipynb
# /usr/local/lib/python3.11/dist-packages/holoviews/examples/user_guide/03-Applying_Customizations.ipynb
# /usr/local/lib/python3.11/dist-packages/holoviews/examples/user_guide/02-Composing_Elements.ipynb
# ...

# %%
# !mv /content/Object_Detection.ipynb Code-Alpha-AI-Internship/
# !mv /content/runs Code-Alpha-AI-Internship/
# Out:
# mv: cannot stat '/content/Object_Detection.ipynb': No such file or directory
# mv: cannot stat '/content/runs': No such file or directory
